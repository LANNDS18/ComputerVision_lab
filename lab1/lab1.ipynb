# %%
import cv2
import numpy as np

a = np.array([[3, 0, -1], [2, -5, 4], [-3, 1, 3]])
b = np.linalg.det(a)
np.linalg.inv([[1, 0, -3],[2, -2, 1],[0, -1 ,3]])
# Out:
# array([[-5.,  3., -6.],
#        [-6.,  3., -7.],
#        [-2.,  1., -2.]])

# %%
import matplotlib.image as mpimg
img = mpimg.imread('../liverpool_church.jpeg')
img.shape
# Out:
# (658, 1194, 3)

# %%
import matplotlib.pyplot as plt
im_crop = img[0:500, 0:500, :]
plt.imshow(im_crop)

# %%
img_c = img[:,:,0]
plt.imshow(img_c)
plt.show()

# %%
from PIL import Image
img = Image.open('../liverpool_church.jpeg')
img.size
# Out:
# (1194, 658)

# %%
newsize = (600, 600)
img_resize = img.resize(newsize)
img_resize.size
# Out:
# (600, 600)

# %%
from PIL import Image
img = Image.open('../liverpool_church.jpeg')
img_grey = img.convert('LA')
img_grey.show()

# %%
img = cv2.imread('../liverpool_church.jpeg')
cv2.imwrite('save_cv2.png',img)
# Out:
# True

# %%
length = int(img.shape[0]/2)
img_half = img[0:length, :, :]
cv2.imwrite('half.png',img_half)
# Out:
# True

# %%
plt.imshow(img_half)
